# %%
import os
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
workPath = os.path.join(os.path.curdir)
inputPath = os.path.join(os.path.curdir, "input")
outputPath = os.path.join(os.path.curdir, "output")
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# %load_ext autoreload
# %autoreload 2

# %%
import ps2
LR_map, RL_map = ps2.Q1(inputPath, outputPath)

# %%
plt.imshow(LR_map)

# %%
plt.imshow(RL_map)

# %%
pair1_D_L = cv2.imread(os.path.join(inputPath, "pair1-D_L.png"))
pair1_D_R = cv2.imread(os.path.join(inputPath, "pair1-D_R.png"))
D_L, D_R = ps2.Q2(inputPath, outputPath)

# %%
plt.imshow(pair1_D_L)

# %%
plt.imshow(D_L)

# %%
plt.imshow(pair1_D_R)

# %%
plt.imshow(D_R)

# %%
pair2_D_L = cv2.imread(os.path.join(inputPath, "pair2-L.png"))
pair2_D_R = cv2.imread(os.path.join(inputPath, "pair2-R.png"))
D_L, D_R = ps2.Q3(inputPath, outputPath)

# %%
plt.imshow(pair2_D_L)

# %%
plt.imshow(D_L)

# %%
plt.imshow(pair2_D_R)

# %%
plt.imshow(D_R)
