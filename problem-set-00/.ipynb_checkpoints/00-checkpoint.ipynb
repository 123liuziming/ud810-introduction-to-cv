# %%
from solve import *
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np

rootPath = os.path.join(os.path.curdir, "problem-set-00")
inputPath = os.path.join(rootPath, "input")
outputPath = os.path.join(rootPath, "output")

img1 = cv2.imread(os.path.join(inputPath, "01.png"))
img2 = cv2.imread(os.path.join(inputPath, "02.png"))

img1, img2 = Q1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-34995400025c> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 rootPath = os.path.join(os.path.curdir, "problem-set-00")
#       5 inputPath = os.path.join(rootPath, "input")
#       6 outputPath = os.path.join(rootPath, "output")
#
# NameError: name 'os' is not defined

# %%
# show Image1
plt.figure("Image1")
plt.imshow(img1)
plt.title("Image1")
plt.show()

# %%
# show Image2
plt.figure("Image2")
plt.imshow(img2)
plt.title("Image2")
plt.show()

# %%
img1, img1Green, img1Red = Q2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-d807c7b49d20> in <module>
# ----> 1 img1, img1Green, img1Red = Q2()
#
# NameError: name 'Q2' is not defined

# %%
# show transImage
plt.figure("transImage")
plt.imshow(img1)
plt.title("transImage")
plt.show()
