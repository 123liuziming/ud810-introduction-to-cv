# %%
from solve import Q1, Q2, Q3, Q4, Q5
import matplotlib.pyplot as plt
import cv2
import os


rootPath = os.path.curdir
inputPath = os.path.join(rootPath, "input")
outputPath = os.path.join(rootPath, "output")

img1 = cv2.imread(os.path.join(inputPath, "01.png"))
img1Rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(os.path.join(inputPath, "02.png"))
img2Rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
# show Image1
plt.figure("Image1")
plt.imshow(img1Rgb)
plt.title("Image1")
plt.show()

# %%
# show Image2
plt.figure("Image2")
plt.imshow(img2Rgb)
plt.title("Image2")
plt.show()

# %%
_img1, img1Green, img1Red = Q2(outputPath, img1)
_imgRgb = cv2.cvtColor(_img1, cv2.COLOR_BGR2RGB)

# %%
# show transImage
plt.figure("transImage")
plt.imshow(_imgRgb)
plt.title("transImage")
plt.show()

# %%
# show transImage
plt.figure("ImageGreen")
plt.imshow(img1Green, cmap = "gray")
plt.title("ImageGreen")
plt.show()

# %%
# show transImage
plt.figure("ImageRed")
plt.imshow(img1Red, cmap = "gray")
plt.title("ImageRed")
plt.show()

# %%
_imgReplace = Q3(outputPath, img1, img2)
plt.figure("ImageReplace")
plt.imshow(cv2.cvtColor(_imgReplace, cv2.COLOR_BGR2RGB))
plt.title("ImageReplace")
plt.show()

# %%
minPixel, maxPixel, meanPixel, stDeviation, img1Greenb, img1Greenc, img1Greend = Q4(outputPath, img1Green)

print("minPixel is %f" % minPixel)
print("maxPixel is %f" % maxPixel)
print("meanPixel is %f" % meanPixel)
print("stDeviation is %f" % stDeviation)
# Out:
# minPixel is 0.000000
# maxPixel is 255.000000
# meanPixel is 82.247167
# stDeviation is 38.124999

# %%
plt.figure("img1Greenb")
plt.imshow(img1Greenb, cmap = "gray")
plt.show()

# %%
plt.figure("img1Greenc")
plt.imshow(img1Greenc, cmap = "gray")
plt.title("img1Greenc")
plt.show()

# %%
plt.figure("img1Greend")
plt.imshow(img1Greend, cmap = "gray")
plt.title("img1Greend")
plt.show()

# %%
imgBlur1, imgBlur2 = Q5(outputPath, img1)

# %%
plt.figure("img1Blur1")
plt.imshow(cv2.cvtColor(imgBlur1, cv2.COLOR_BGR2RGB))
plt.title("img1Blur1")
plt.show()

# %%
plt.figure("img1Blur2")
plt.imshow(cv2.cvtColor(imgBlur2, cv2.COLOR_BGR2RGB))
plt.title("img1Blur2")
plt.show()
