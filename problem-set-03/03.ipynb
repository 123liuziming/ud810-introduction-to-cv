# %%
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
workPath = os.path.join(os.path.curdir)
inputPath = os.path.join(os.path.curdir, "input")
outputPath = os.path.join(os.path.curdir, "output")
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# %load_ext autoreload
# %autoreload 2

# %%
os.chdir("/Users/liuziming/Desktop/ud810-introduction to cv/problem-set-03")
import ps3
M1, M2, _= ps3.Q1(inputPath)
print("M1 is:")
print(M1)
print("M2 is:")
print(M2)
# Out:
# M1 is:
# [[ 0.76785834 -0.49384797 -0.02339781  0.00674445]
#  [-0.0852134  -0.09146818 -0.90652332 -0.08775678]
#  [ 0.18265016  0.29882917 -0.07419242  1.        ]]
# M2 is:
# [[ 0.45827554 -0.29474237 -0.01395746  0.0040258 ]
#  [-0.05085589 -0.0545847  -0.54105993 -0.05237592]
#  [ 0.10900958  0.17834548 -0.04426782  0.5968205 ]]

# %%
F_lstsq, F_SVD, F_lstsq_r2, img_a, img_b = ps3.Q2(inputPath, outputPath)
print("F_lstsq is:")
print(F_lstsq)
print("F_SVD is:")
print(F_SVD)
print("F_lstsq_r2 is:")
print(F_lstsq_r2)
# Out:
# F_lstsq is:
# [[-6.60675944e-07  7.90642197e-06 -1.88480992e-03]
#  [ 8.82674944e-06  1.21863596e-06  1.72276843e-02]
#  [-9.08539064e-04 -2.64201801e-02  1.00000000e+00]]
# F_SVD is:
# [-1.52293273e-06  7.75971784e-07  9.75849787e-06 -9.28925970e-06
#  -1.84335298e-03  3.51080245e-03  2.64322926e-03  3.12546916e-02
#   9.99500092e-01]
# F_lstsq_r2 is:
# [[-5.35883058e-07  7.89972529e-06 -1.88480998e-03]
#  [ 8.83820595e-06  1.21802118e-06  1.72276843e-02]
#  [-9.08539027e-04 -2.64201801e-02  1.00000000e+00]]

# %%
plt.imshow(cv2.cvtColor(img_a, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(img_b, cv2.COLOR_BGR2RGB))
