# %%
import os
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
workPath = os.path.join(os.path.curdir)
inputPath = os.path.join(os.path.curdir, "input")
outputPath = os.path.join(os.path.curdir, "output")
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# %load_ext autoreload
# %autoreload 2

# %%
import solve
canny = solve.Q1(inputPath, outputPath)
plt.imshow(canny, "gray")

# %%
H, peaks, img_line = solve.Q2(inputPath, outputPath, canny)
plt.imshow(H, "gray")

# %%
fig = plt.figure()
plt.imshow(H, 'hot')
plt.plot(peaks[:, 1], peaks[:, 0], 'rs')
fig.savefig('output/ps1-2-b-1.png')

# %%
plt.imshow(img_line)

# %%
img_smoothed, canny_origin, canny_smoothed, H, peaks, img_line = solve.Q3(inputPath, outputPath)
plt.imshow(img_smoothed)

# %%
plt.imshow(canny_origin)

# %%
plt.imshow(canny_smoothed)

# %%
plt.imshow(H)

# %%
fig = plt.figure()
plt.imshow(H, 'hot')
plt.plot(peaks[:, 1], peaks[:, 0], 'rs')
fig.savefig('output/ps1-3-c-1.png')

# %%
plt.imshow(img_line)

# %%
origin_img, img_smooth, img_canny, H, img_line, peaks = solve.Q4(inputPath, outputPath)
plt.imshow(origin_img)
# Out:
# rho is 350
# theta is 166
# rho is 1138
# theta is 53
# rho is 1116
# theta is 53
# rho is 330
# theta is 166

# %%
plt.imshow(img_smooth)

# %%
plt.imshow(img_canny)

# %%
fig = plt.figure()
plt.imshow(H, 'hot')
plt.plot(peaks[:, 1], peaks[:, 0], 'rs')
fig.savefig('output/ps1-4-c-1.png')

# %%
plt.imshow(img_line)
